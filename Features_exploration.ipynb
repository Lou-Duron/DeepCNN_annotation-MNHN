# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras 
from tensorflow.keras.models import Model
from ModuleLibrary.metrics import BA, MCC
from ModuleLibrary.plots import Features_exploration, Chromosome_prediction

# %%
feature = 'exon_start'

# %%
path = f'Results/newHS37_{feature}/best_metrics_model.hdf5'
pred = f'Predictions/HS37_{feature}/chr1.npy'

# %%
exp = Features_exploration(path, pred, 'HS37', 1, 0, motif=feature)

# %%
pred_tmp = np.load(f'Predictions/HS37_{feature}/chr1.npy')

# %%
arr = np.where(pred_tmp>.99)[0]

# %%
print(pred_tmp.shape)
print(arr.shape)
# Out:
# (249250621, 1)
# (7376,)

# %%
for i in arr[:20]:
    print(i)
    exp.explore(i)
# Out:
# 90478
# Prediction : 0.9929999709129333
# Motif found : ['g' 'g' 't' 'c' 't'] at 140. Contrib : 1.653
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 1.622
# 228642
# Prediction : 0.996999979019165
# Motif found : ['g' 'g' 't' 'g' 'a'] at 150. Contrib : 1.303
# Motif found : ['a' 'g' 't' 'g' 'a'] at 154. Contrib : 0.967
# 236806
# Prediction : 0.9919999837875366
# Motif found : ['g' 'g' 't' 'c' 't'] at 140. Contrib : 1.66
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 1.623
# 322227
# Prediction : 0.9929999709129333
# Motif found : ['g' 'g' 't' 'g' 'c'] at 78. Contrib : 0.552
# Motif found : ['g' 'g' 't' 'g' 'a'] at 137. Contrib : 0.878
# Motif found : ['c' 'g' 't' 'g' 'a'] at 150. Contrib : 2.283
# Motif found : ['a' 'g' 't' 'a' 'a'] at 154. Contrib : 2.583
# 329975
# Prediction : 0.9919999837875366
# Motif found : ['g' 'g' 't' 'g' 'a'] at 150. Contrib : 1.042
# 350628
# Prediction : 0.9919999837875366
# Motif found : ['t' 'g' 't' 'a' 't'] at 136. Contrib : 0.651
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 2.061
# 381812
# Prediction : 0.9909999966621399
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 2.192
# 439567
# Prediction : 0.9959999918937683
# Motif found : ['g' 'g' 't' 'g' 'a'] at 150. Contrib : 0.803
# Motif found : ['g' 'g' 't' 'g' 'g'] at 157. Contrib : 1.812
# Motif found : ['g' 'g' 't' 'g' 'g'] at 170. Contrib : 0.774
# 461287
# Prediction : 0.9980000257492065
# Motif found : ['g' 'g' 't' 'g' 'a'] at 150. Contrib : 1.781
# Motif found : ['t' 'g' 't' 'c' 'a'] at 156. Contrib : 0.846
# 534411
# Prediction : 0.9950000047683716
# Motif found : ['g' 'g' 't' 'g' 'a'] at 150. Contrib : 0.76
# 546652
# Prediction : 0.9959999918937683
# Motif found : ['c' 'g' 't' 'a' 'a'] at 94. Contrib : 0.545
# Motif found : ['g' 'g' 't' 'g' 't'] at 186. Contrib : 1.135
# Motif found : ['t' 'g' 't' 'g' 'a'] at 188. Contrib : 0.801
# 578378
# Prediction : 0.9959999918937683
# Motif found : ['a' 'g' 't' 'a' 'a'] at 150. Contrib : 1.916
# Motif found : ['a' 'g' 't' 'g' 'a'] at 154. Contrib : 1.426
# 714471
# Prediction : 0.9980000257492065
# Motif found : ['g' 'g' 't' 'a' 'c'] at 150. Contrib : 1.109
# 739601
# Prediction : 0.9909999966621399
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 1.467
# 763154
# Prediction : 0.9980000257492065
# Motif found : ['t' 'g' 't' 't' 'a'] at 145. Contrib : 2.741
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 2.642
# 783185
# Prediction : 0.9959999918937683
# Motif found : ['g' 'g' 't' 'a' 'g'] at 150. Contrib : 2.098
# Motif found : ['g' 'g' 't' 'g' 'g'] at 154. Contrib : 2.218
# 789263
# Prediction : 0.9929999709129333
# Motif found : ['g' 'g' 't' 'a' 'a'] at 52. Contrib : 1.993
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 0.516
# Motif found : ['t' 'g' 't' 'a' 'a'] at 222. Contrib : 1.669
# Motif found : ['g' 'g' 't' 'g' 'c'] at 233. Contrib : 1.012
# Motif found : ['g' 'g' 't' 't' 'c'] at 271. Contrib : 0.65
# 794085
# Prediction : 0.9900000095367432
# Motif found : ['g' 'g' 't' 'a' 'g'] at 8. Contrib : 0.517
# Motif found : ['g' 'g' 't' 'g' 'a'] at 150. Contrib : 1.301
# Motif found : ['g' 'g' 't' 'g' 'a'] at 191. Contrib : 0.573
# 796652
# Prediction : 0.9940000176429749
# Motif found : ['t' 'g' 't' 'a' 'a'] at 150. Contrib : 3.031
# Motif found : ['a' 'g' 't' 'a' 'c'] at 154. Contrib : 2.941
# 800878
# Prediction : 0.9919999837875366
# Motif found : ['g' 'g' 't' 'a' 'a'] at 150. Contrib : 1.616
# Motif found : ['g' 'g' 't' 'g' 'c'] at 157. Contrib : 0.974

# %%
tmp = Chromosome_prediction([f'HS37_{feature}/chr1.npy'], 'HS37', 1, False, 301, 0, 'RNA', mode='strand+')

# %%
tmp.update_plots(1371000, 400)
