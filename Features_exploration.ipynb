# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras 
from tensorflow.keras.models import Model
from ModuleLibrary.metrics import BA, MCC
from ModuleLibrary.plots import Features_exploration, Chromosome_prediction
# Out:
# 2022-04-07 16:04:50.310609: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
feature = 'exon_start'

# %%
path = f'Results/newHS37_{feature}/best_metrics_model.hdf5'
pred = f'Predictions/HS37_{feature}/chr1.npy'

# %%
exp = Features_exploration(path, pred, 'HS37', 1, 0, motif=feature)

# %%
pred_tmp = np.load(f'Predictions/HS37_{feature}/chr1.npy')

# %%
arr = np.where(pred_tmp>.99)[0]

# %%
print(pred_tmp.shape)
print(arr.shape)
# Out:
# (249250621, 1)
# (2420,)

# %%
res = []
for i in arr[:5]:
    res.append(exp.explore(i))
for el in res:
    print(el.shape)
# Out:
# 329648
# 2022-04-07 09:42:10.423270: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-04-07 09:42:10.436792: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2200000000 Hz
# 2022-04-07 09:42:10.538013: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-04-07 09:42:10.872311: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2022-04-07 09:42:11.226852: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-04-07 09:42:11.567375: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# ...

# %%
tmp = Chromosome_prediction([f'HS37_{feature}/chr1.npy'], 'HS37', 1, False, 301, 0, 'RNA', mode='strand+')

# %%
tmp.update_plots(1371000, 400)
