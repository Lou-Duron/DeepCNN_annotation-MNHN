# %%
from ModuleLibrary.plots import training_metrics
# Out:
# 2022-04-15 09:47:24.896732: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
training_metrics('prot1')
training_metrics('prot2')
training_metrics('prot3')
training_metrics('prot4')
training_metrics('prot5')
training_metrics('prot6')
training_metrics('prot7')
