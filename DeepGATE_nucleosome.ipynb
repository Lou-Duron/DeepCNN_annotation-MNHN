# %%
import numpy as np
from tensorflow.keras.models import Model, load_model
import h5py
from ModuleLibrary.metrics import mae_cor, correlate
from DeepGATE.DeepGATE import *
# Out:
# 2022-06-23 13:10:22.939064: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
seq = np.load('data_lou/sequence.npy')
lab = np.load('data_lou/labels.npy')
test = Explorer('data_lou/model.h5', custom_objects={'mae_cor': mae_cor, 'correlate':correlate})

# %%
x = 3000110
data = seq[x:x+2001]
test.explore(data)

# %%
x = 3000011
data = seq[x:x+2001]
test.explore(data)

# %%
x = 3000021
data = seq[x:x+2001]
test.explore(data)
