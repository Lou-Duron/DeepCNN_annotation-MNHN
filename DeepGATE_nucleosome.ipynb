# %%
import numpy as np
from ModuleLibrary.metrics import mae_cor, correlate
from DeepGATE.DeepGATE import *
# Out:
# 2022-06-23 13:38:58.914326: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
seq = np.load('data_lou/sequence.npy')
lab = np.load('data_lou/labels.npy')
test = Explorer('data_lou/model.h5', custom_objects={'mae_cor': mae_cor, 'correlate':correlate})
# Out:
# 2022-06-23 13:39:02.911159: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-06-23 13:39:03.718414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:73:00.0 name: NVIDIA Quadro P6000 computeCapability: 6.1
# coreClock: 1.645GHz coreCount: 30 deviceMemorySize: 23.87GiB deviceMemoryBandwidth: 403.49GiB/s
# 2022-06-23 13:39:03.718492: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-06-23 13:39:03.728105: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-06-23 13:39:03.728181: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-06-23 13:39:03.730123: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-06-23 13:39:03.730522: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-06-23 13:39:03.731673: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-06-23 13:39:03.732751: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-06-23 13:39:03.732934: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-06-23 13:39:03.734741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-06-23 13:39:03.735894: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-23 13:39:03.739537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:73:00.0 name: NVIDIA Quadro P6000 computeCapability: 6.1
# coreClock: 1.645GHz coreCount: 30 deviceMemorySize: 23.87GiB deviceMemoryBandwidth: 403.49GiB/s
# 2022-06-23 13:39:03.741252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-06-23 13:39:03.741290: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-06-23 13:39:04.297252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-23 13:39:04.297280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-06-23 13:39:04.297287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-06-23 13:39:04.299640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 23672 MB memory) -> physical GPU (device: 0, name: NVIDIA Quadro P6000, pci bus id: 0000:73:00.0, compute capability: 6.1)

# %%
x = 3000110
data = seq[x:x+2001]
test.explore(data)
# Out:
# 2022-06-23 13:39:07.794077: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-06-23 13:39:07.808859: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2200000000 Hz
# 2022-06-23 13:39:07.890787: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-06-23 13:39:08.225694: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2022-06-23 13:39:08.581066: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-06-23 13:39:08.920815: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc2d813b5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc2d81f6790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
res = np.transpose(test.layers[0].input_contrib)
res.shape
# Out:
# (2001, 4)

# %%
x = 3000011
data = seq[x:x+2001]
test.explore(data)

# %%
x = 3000021
data = seq[x:x+2001]
test.explore(data)
