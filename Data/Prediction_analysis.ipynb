# %%
from ModuleLibrary.plots import Chromosome_prediction, prediction_density, training_metrics
from ModuleLibrary.utils import test
import os
import numpy as np
# Out:
# 2022-03-10 15:17:55.886817: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
RNA = ['multi3_RNA_start+_pred.npy','multi3_RNA_start-_pred.npy']

# %%
prediction_density(RNA, 'Panu', 1, 'RNA', 2000, 301, annot_end=False)

# %%
plot = Chromosome_prediction(files_list = RNA, 
                            species = 'Panu', 
                            chr_nb = '1',
                            window = 301,
                            conv = 300,
                            annotation_type = 'RNA',
                            mode = 'start',
                            GC = False)

# %%
plot.update_annotation(annotation_type = 'GENE', mode = 'start')

# %%
plot.update_plots(plot_start=660000, plot_range=50000)
# Out:
# (218171093,)
# (218171093,)

# %%
plot.update_plots(plot_start=218100000, plot_range=100000)
# Out:
# (218171093,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_41667/279087986.py in <module>
# ----> 1 plot.update_plots(plot_start=218100000, plot_range=100000)
#
# ~/mnhn/ModuleLibrary/plots.py in update_plots(self, plot_start, plot_range)
#     240             name = name.replace('.npy','')
#     241             print(pred.shape)
# --> 242             plt.plot(self.nuc[x:x+y], pred[x:x+y], label=name)
#     243         plt.legend()
#     244         plt.show()
#
# ~/anaconda3/envs/tf2.5/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
# ...

# %%
plot.update_conv(0)
