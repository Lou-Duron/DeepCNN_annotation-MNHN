# %%
from ModuleLibrary.plots import Chromosome_prediction, prediction_density, training_metrics, prediction_quality
import os
import numpy as np
# Out:
# 2022-03-29 08:44:11.930565: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
gene = ['HS37_gene_start/chr1.npy','HS37_gene_stop/chr1.npy']
exon = ['HS37_exon_start/chr1.npy','HS37_exon_stop/chr1.npy']
cds = ['HS37_cds_start/chr1.npy','HS37_cds_stop/chr1.npy']
rna = ['HS37_rna_start/chr1.npy','HS37_rna_stop/chr1.npy']
rt = ['test_retrain.npy', 'HS37_exon_start/chr1.npy']
b = ['Basenji2.npy','BasenjiDNA4.npy']
full = ['fullHSBasenji2.npy']
test = ['testRB.npy']

# %%
prediction_quality(test, 'HS37', 1, 'gene_strand+')
prediction_quality(test, 'HS37', 1, 'gene_strand-')

# %%
plt = Chromosome_prediction(files_list = test, 
                            species = 'HS37', 
                            chr_nb = '1',
                            window = 2001,
                            conv = 100,
                            annotation_type = 'GENE',
                            mode = 'strand+',
                            GC = False)

# %%
plt.update_annotation('GENE')

# %%
plt.update_plots(plot_start=1500000,plot_range=100000)

# %%
plt2.update_plots(plot_start=100000,plot_range=100000)

# %%
plt2.update_plots(plot_start=100000,plot_range=100000)
