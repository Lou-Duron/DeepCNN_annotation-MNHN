# %%
from ModuleLibrary.plots import Chromosome_prediction, prediction_density, training_metrics, prediction_quality
import os
import numpy as np
# Out:
# 2022-03-16 11:34:17.085629: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
RNA = ['multi3_RNA_stop+_pred.npy','multi3_RNA_stop-_pred.npy']
exon = ['multi3_exon_start_pred.npy','multi3_exon_start_w50_pred.npy','multi3_exon_start_w50_reverse_pred.npy']
full = ['HS37_chr1_dilated2.npy', 'HS37_chr1_dilated6.npy']
dilated = ['dilatedValid1.npy','dilatedValid2.npy','dilatedValid3.npy']

# %%
prediction_quality(dilated, 'HS37', 1, 'GENE', mode='strand+')

# %%
prediction_density(dilated, 'HS37', 1, 'GENE', 2000, annot_end=False)

# %%
plot = Chromosome_prediction(files_list = dilated, 
                            species = 'HS37', 
                            chr_nb = '1',
                            window = 2001,
                            conv = 300,
                            annotation_type = 'GENE',
                            mode = 'full',
                            GC = False)

# %%
plot.update_conv(300)

# %%
plot.update_plots(plot_start=850000, plot_range=120000)
# Out:
# (249249493,)
# (249249493,)
# (249249493,)

# %%
plot.update_plots(plot_start=218100000, plot_range=100000)
# Out:
# (218171093,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_41667/279087986.py in <module>
# ----> 1 plot.update_plots(plot_start=218100000, plot_range=100000)
#
# ~/mnhn/ModuleLibrary/plots.py in update_plots(self, plot_start, plot_range)
#     240             name = name.replace('.npy','')
#     241             print(pred.shape)
# --> 242             plt.plot(self.nuc[x:x+y], pred[x:x+y], label=name)
#     243         plt.legend()
#     244         plt.show()
#
# ~/anaconda3/envs/tf2.5/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
# ...

# %%
plot.update_conv(0)
