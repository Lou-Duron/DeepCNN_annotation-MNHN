# %%
from ModuleLibrary.plots import Chromosome_prediction_prot, prediction_density, training_metrics, prediction_quality
import os
import numpy as np
# Out:
# 2022-04-19 14:29:22.210107: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
test = ['test.npy']

# %%
plt = Chromosome_prediction_prot(files_list = test, 
                                species = 'HS37', 
                                chr_nb = '1',
                                annotation_type = 'CDS')

# %%
plt.update_plots(plot_start=879000,plot_range=1000)

# %%
plt.update_conv(0)
